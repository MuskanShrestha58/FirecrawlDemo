# %%
from firecrawl import FirecrawlApp
import json
import requests

# %% [markdown]
# - The previous Key used in firecrawl_basobas.ipynb expired .
# - using another api key

# %% [markdown]
# # Scraping + Crawling using API endpoints provided by Firecrawl

# %%
# Initialize FirecrawlApp with the provided API key
key= "fc-485e7f28681a48ec8d102a0e2c543392"
app = FirecrawlApp(api_key=key)
dpath = "C:/Users/Muskan Shrestha/Desktop/VajraTech/ExploreFirecrawl/output/"

# %%
import requests
import json

# Define the URL and payload
url = "https://api.firecrawl.dev/v0/scrape"

payload = {
    "url": "https://basobaas.com/for-sale",
    "pageOptions": {
        "headers": {},
        "includeHtml": True,
        "includeRawHtml": True,
        "onlyIncludeTags": ["title", "metadata"],
        "onlyMainContent": True,
        "removeTags": [],
        "replaceAllPathsWithAbsolutePaths": True,
        "screenshot": True,
        "waitFor": 1000  # Increased waitFor to 500 ms
    },
    "extractorOptions": {
        "mode": "markdown",
        "extractionPrompt": "Scrape the property name and all of its details related to the property like price, area, floor, beds, bathrooms etc",
        "extractionSchema": {
            "properties": {
                "title": {"type": "string"},
                "description": {"type": "string"},
                "price": {"type": "string"},
                "area": {"type": "string"},
                "location": {"type": "string"},
                "beds": {"type": "integer"},
                "kitchen": {"type": "integer"},
                "bathroom": {"type": "integer"},
                "floor": {"type": "integer"},
                "storeys": {"type": "integer"},
                "agency_name": {"type": "string"},
                "road_access": {"type": "string"},
                "furnishing": {"type": "string"},
                "face_of_direction": {"type": "string"}
            }
        }
    },
    "timeout": 600  # Increased timeout to 600 seconds (10 minutes)
}

# Define the headers
headers = {
    "Authorization": "Bearer fc-485e7f28681a48ec8d102a0e2c543392",
    "Content-Type": "application/json"
}

try:
    # Make the request with a timeout parameter
    response = requests.post(url, json=payload, headers=headers, timeout=1200)  # Timeout of 600 seconds

    # Check the response status code
    if response.status_code == 200:
        # Parse the response JSON
        response_data = response.json()

        # Define the path to save the JSON file
        dpath = "C:/Users/Muskan Shrestha/Desktop/VajraTech/ExploreFirecrawl/output/"

        # Save the response content into a JSON file
        with open(dpath + 'scrapedbyAPI1.json', 'w') as json_file:
            json.dump(response_data, json_file, indent=4)

        print("Content saved to scrapedbyAPI1.json")
    else:
        print(f"Error: {response.status_code}, {response.text}")
except requests.exceptions.Timeout:
    print("The request timed out. Please try increasing the timeout value.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Error: 408, {"success":false,"error":"Request timed out. Increase the timeout by passing `timeout` param to the request.","returnCode":408}

# %%
import requests

url = "https://api.firecrawl.dev/v0/crawl"

payload = {
    "url": "https://basobaas.com/for-sale",
    "crawlerOptions": {
        "includes": ["title","metadata"],
        "excludes": ["header"],
        "generateImgAltText": True,
        "returnOnlyUrls": True,
        "maxDepth": 123,
        "mode": "default",
        "ignoreSitemap": True,
        "limit": 123,
        "allowBackwardCrawling": True,
        "allowExternalContentLinks": True
    },
    "pageOptions": {
        "headers": {},
        "includeHtml": True,
        "includeRawHtml": True,
        "onlyMainContent": True,
        "removeTags": ["<string>"],
        "replaceAllPathsWithAbsolutePaths": True,
        "screenshot": True,
        "waitFor": 1000
    }
}
headers = {
    "Authorization": "Bearer fc-485e7f28681a48ec8d102a0e2c543392",
    "Content-Type": "application/json"
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)
# Out:
# {"jobId":"891cd403-b8c5-475b-8b0d-bf7eb4419f69"}

# %%
job_id = "381bf783-d908-41bf-8af4-6aa94942eae6"

status_url = "https://api.firecrawl.dev/v0/crawl/status/{jobId}"

headers = {"Authorization": "Bearer fc-485e7f28681a48ec8d102a0e2c543392"}

response = requests.request("GET", status_url, headers=headers)
print(response.status_code)
print(response.content)
print(response.text)
# Out:
# 404
# b'{"error":"Job not found"}'
# {"error":"Job not found"}

# %% [markdown]
# # Using Crawler to crawl basobas sale page

# %%
app = FirecrawlApp(api_key=key)

crawl_result = app.crawl_url('https://basobaas.com/for-sale', {'crawlerOptions': {'excludes': ['header/*']}})

# Get the markdown
for result in crawl_result:
    print(result['markdown'])
# Out:
# [![Basobaas](https://basobaas.com/images/basobaas_logo_1.svg)Basobaas](/)
#
# ...
#
# [FREEPOST PROPERTY](/post-property)
#
# [SIGN IN/SIGN UP](/login)
#
#
#
# Location
#
# More filters
#
# Clear Filters
#
# #### Showing Results for Properties For Sale in Nepal
#
# Save this search
#
# Relevance
#
# ![Residential Land On Sale-image-1](https://basobaas.com/_next/image?url=https%3A%2F%2Fapi.basobaas.com%2Fapi%2Ffiles%2Fa4alnectuppemjo%2Fvd6fs7yl5h3nk2u%2Fvlcsnap_2024_07_16_14h08m42s106_u3v9QugeX9.webp%3Fthumb%3D310x0&w=3840&q=75)
#
# ![Residential Land On Sale-image-2](https://basobaas.com/_next/image?url=https%3A%2F%2Fapi.basobaas.com%2Fapi%2Ffiles%2Fa4alnectuppemjo%2Fvd6fs7yl5h3nk2u%2Fvlcsnap_2024_07_16_14h10m44s895_JSzqzetTDH.webp%3Fthumb%3D310x0&w=3840&q=75)
#
# ...

# %%
app = FirecrawlApp(api_key=key)

crawl_result = app.crawl_url('https://basobaas.com/for-sale')

# Get the markdown
for result in crawl_result:
    print(result['markdown'])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 app = FirecrawlApp(api_key=key)
# ----> 3 crawl_result = app.crawl_url('https://basobaas.com/for-sale')
#       5 # Get the markdown
#       6 for result in crawl_result:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\firecrawl\firecrawl.py:159, in FirecrawlApp.crawl_url(self, url, params, wait_until_done, timeout, idempotency_key)
#     157         return {'jobId': job_id}
#     158 else:
# --> 159     self._handle_error(response, 'start crawl job')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\firecrawl\firecrawl.py:299, in FirecrawlApp._handle_error(self, response, action)
#     297     raise Exception(f'Failed to {action}. Status code: {response.status_code}. Error: {error_message}')
#     298 else:
# ...

# %% [markdown]
# # Extracting using LLM provided by Firecrawl

# %%
from pydantic import BaseModel, Field
from typing import List

# %%
from pydantic import BaseModel, Field
from typing import List
from firecrawl import FirecrawlApp

# Define the schema for individual articles
class PageSchema(BaseModel):
    title: str
    description: str
    land_area: str
    location: str
    amneties: list
    media_urls: list
    price: str
    by: str
    URL: str

# Define the schema for top articles, allowing a maximum of 5 articles
class TopPropertiesSchema(BaseModel):
    top: List[PageSchema] = Field(..., max_items=10, description="Top 10 properties")

# Initialize the FirecrawlApp with your API key
app = FirecrawlApp(api_key="fc-485e7f28681a48ec8d102a0e2c543392")

# Define the payload for scraping the URL
data = app.scrape_url('https://basobaas.com/for-sale', {
    'extractorOptions': {
        'extractionSchema': TopPropertiesSchema.model_json_schema(),
        'mode': 'llm-extraction'
    },
    'pageOptions': {
        'onlyMainContent': True
    }
})

# Extract the relevant data
data_extracted = data.get("llm_extraction")

# Print the extracted data
print(data_extracted)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 25
#      22 app = FirecrawlApp(api_key="fc-485e7f28681a48ec8d102a0e2c543392")
#      24 # Define the payload for scraping the URL
# ---> 25 data = app.scrape_url('https://basobaas.com/for-sale', {
#      26     'extractorOptions': {
#      27         'extractionSchema': TopPropertiesSchema.model_json_schema(),
#      28         'mode': 'llm-extraction'
#      29     },
#      30     'pageOptions': {
#      31         'onlyMainContent': True
#      32     }
#      33 })
#      35 # Extract the relevant data
#      36 data_extracted = data.get("llm_extraction")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\firecrawl\firecrawl.py:86, in FirecrawlApp.scrape_url(self, url, params)
#      84 elif response.status_code in [402, 408, 409, 500]:
# ...

# %%
# Extraction Output 
# Save the extracted data to a JSON file
output_file = dpath+ "llm_extracted_data.json"
with open(output_file, 'w') as json_file:
    json.dump(data_extracted, json_file, indent=4)

print(f"Content saved to {output_file}")
# Out:
# Content saved to C:/Users/Muskan Shrestha/Desktop/VajraTech/ExploreFirecrawl/output/llm_extracted_data.json

# %% [markdown]
# # Removed Amneties added ana to the land area to check if it causes any difference

# %%
from pydantic import BaseModel, Field
from typing import List
from firecrawl import FirecrawlApp

# Define the schema for individual articles
class PageSchema(BaseModel):
    title: str
    description: str
    land_area_ana: str
    location: str
    media_urls: list
    price: str
    by: str
    URL: str

# Define the schema for top articles, allowing a maximum of 5 articles
class TopPropertiesSchema(BaseModel):
    top: List[PageSchema] = Field(..., max_items=5, description="Top 5 properties")

# Initialize the FirecrawlApp with your API key
app = FirecrawlApp(api_key="fc-485e7f28681a48ec8d102a0e2c543392")

# Define the payload for scraping the URL
data = app.scrape_url('https://basobaas.com/for-sale',{
    'extractorOptions': {
        'extractionSchema': TopPropertiesSchema.model_json_schema(),
        'mode': 'llm-extraction'
    },
    'pageOptions': {
        'onlyMainContent': True,
        'timeout': 5000
    }
})

# Extract the relevant data
data_extracted = data.get("llm_extraction")

# Print the extracted data
print(data_extracted)
# Extraction Output 
# Save the extracted data to a JSON file
dpath = "C:/Users/Muskan Shrestha/Desktop/VajraTech/ExploreFirecrawl/output/"
output_file = dpath+ "llm_extracted_data2.json"
with open(output_file, 'w') as json_file:
    json.dump(data_extracted, json_file, indent=4)

print(f"Content saved to {output_file}")
# Out:
# {'top': [{'title': 'Residential Land On Sale', 'description': '', 'land_area_ana': 'N/A', 'location': 'Shital Height, Lalitpur', 'media_urls': ['https://basobaas.com/_next/image?url=https%3A%2F%2Fapi.basobaas.com%2Fapi%2Ffiles%2Fa4alnectuppemjo%2Fvd6fs7yl5h3nk2u%2Fvlcsnap_2024_07_16_14h08m42s106_u3v9QugeX9.webp%3Fthumb%3D310x0&w=3840&q=75', 'https://basobaas.com/_next/image?url=https%3A%2F%2Fapi.basobaas.com%2Fapi%2Ffiles%2Fa4alnectuppemjo%2Fvd6fs7yl5h3nk2u%2Fvlcsnap_2024_07_16_14h10m44s895_JSzqzetTDH.webp%3Fthumb%3D310x0&w=3840&q=75', 'https://basobaas.com/_next/image?url=https%3A%2F%2Fapi.basobaas.com%2Fapi%2Ffiles%2Fa4alnectuppemjo%2Fvd6fs7yl5h3nk2u%2Fvlcsnap_2024_07_16_14h10m13s880_Vsa35c8TvN.webp%3Fthumb%3D310x0&w=3840&q=75', 'https://basobaas.com/_next/image?url=https%3A%2F%2Fapi.basobaas.com%2Fapi%2Ffiles%2Fa4alnectuppemjo%2Fvd6fs7yl5h3nk2u%2Fvlcsnap_2024_07_16_14h09m29s589_kxhvkf1Cnl.webp%3Fthumb%3D310x0&w=3840&q=75', 'https://basobaas.com/_next/image?url=https%3A%2F%2Fapi.ba
# ...

# %% [markdown]
# - This gives clean results but
# - the results are not completely reliable
# - It sometimes does extract the values for the fields in the schema and if I rerun it, there are chances that the values for same fields might not get extracted.
# - It seems like the max_item and number of fields to be extracted in the schema somehow affects the result generated.

# %%
# CHecking if it works better in smaller schema
from pydantic import BaseModel, Field
from typing import List
from firecrawl import FirecrawlApp

# Define the schema for individual articles
class PageSchema(BaseModel):
    title: str
    description: str
    land_area_ana: str
    location: str
    media_urls: list
    price: str
    by: str
    URL: str

# Define the schema for top articles, allowing a maximum of 5 articles
class TopPropertiesSchema(BaseModel):
    top: List[PageSchema] = Field(..., max_items=5, description="Top 5 properties")

# Initialize the FirecrawlApp with your API key
app = FirecrawlApp(api_key="fc-485e7f28681a48ec8d102a0e2c543392")

# Define the payload for scraping the URL
data = app.scrape_url('https://basobaas.com/for-sale',{
    'extractorOptions': {
        'extractionSchema': TopPropertiesSchema.model_json_schema(),
        'mode': 'llm-extraction'
    },
    'pageOptions': {
        'onlyMainContent': True,
        'timeout': 5000
    }
})

# Extract the relevant data
data_extracted = data.get("llm_extraction")

# Print the extracted data
print(data_extracted)
# Extraction Output 
# Save the extracted data to a JSON file
dpath = "C:/Users/Muskan Shrestha/Desktop/VajraTech/ExploreFirecrawl/output/"
output_file = dpath+ "llm_extracted_data3.json"
with open(output_file, 'w') as json_file:
    json.dump(data_extracted, json_file, indent=4)

print(f"Content saved to {output_file}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      22 app = FirecrawlApp(api_key="fc-485e7f28681a48ec8d102a0e2c543392")
#      24 # Define the payload for scraping the URL
# ---> 25 data = app.scrape_url('https://basobaas.com/for-sale',{
#      26     'extractorOptions': {
#      27         'extractionSchema': TopPropertiesSchema.model_json_schema(),
#      28         'mode': 'llm-extraction'
#      29     },
#      30     'pageOptions': {
#      31         'onlyMainContent': True,
#      32         'timeout': 5000
#      33     }
#      34 })
#      36 # Extract the relevant data
#      37 data_extracted = data.get("llm_extraction")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\firecrawl\firecrawl.py:73, in FirecrawlApp.scrape_url(self, url, params)
#      71             scrape_params[key] = value
# ...

# %% [markdown]
# Both of the output files are in the output folder of this directory.
